# %% [markdown]
# # IWS
# The main aim is to create a knowledge base

# %%
# !pip install google-api-python-client

# %%
api_key = "AIzaSyAffIrMqkGYI6tgqceJkQm0TjR7cB7NlIc"

# %%
from apiclient.discovery import build

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %%
req = youtube.search().list(q = 'bully algorithm', type='video' ,part='snippet', maxResults = 10)

# %%
result = req.execute()

# %%
search = result['items'][0]['id']['videoId']

# %%
search = str(search)

# %%
search
# Out:
# 'z6PQGVcKXrk'

# %%
search = 'https://www.youtube.com/watch?v=' + search

# %%
import urllib.request
from urllib.parse import urlencode
import webbrowser

# %%
weburl = urllib.request.urlopen(search)

# %%
print(weburl.read())
# Out:
# b'<!doctype html><html  style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en-GB" dir="ltr" gl="IN"><head><meta http-equiv="X-UA-Compatible" content="IE=edge" /><script >var ytcfg = {d: function() {return (window.yt && yt.config_) || ytcfg.data_ || (ytcfg.data_ = {});},get: function(k, o) {return (k in ytcfg.d()) ? ytcfg.d()[k] : o;},set: function() {var a = arguments;if (a.length > 1) {ytcfg.d()[a[0]] = a[1];} else {for (var k in a[0]) {ytcfg.d()[k] = a[0][k];}}}};window.ytcfg.set(\'EMERGENCY_BASE_URL\', "\\/error_204?client.name=1\\u0026client.version=2.20201120.01.00\\u0026level=ERROR\\u0026t=jserror");</script>  \n<script >var $jscomp=$jscomp||{};$jscomp.scope={};$jscomp.arrayIteratorImpl=function(a){var d=0;return function(){return d<a.length?{done:!1,value:a[d++]}:{done:!0}}};$jscomp.arrayIterator=function(a){return{next:$jscomp.arrayIteratorImpl(a)}};$jscomp.ASSUME_ES5=!1;$jscomp.ASSUME_NO_NATIVE_MAP=!1;$jscomp.ASSUME_NO_NATIVE_SET=!1;$jscomp.SIMPLE_FROUND_P
# ...

# %%
webbrowser.open(search)
# Out:
# True

# %%
from __future__ import print_function
import json
import urllib


query = 'Taylor Swift'
service_url = 'https://kgsearch.googleapis.com/v1/entities:search'
params = {
    'query': query,
    'limit': 10,
    'indent': True,
    'key': api_key,
}
url = service_url + '?' + urllib.parse.urlencode(params)
response = json.loads(urllib.request.urlopen(url).read())
for element in response['itemListElement']:
  print(element['result']['name'] + ' (' + str(element['resultScore']) + ')'),
    'indent': True,
    'key': api_key,
}
url = service_url + '?' + urlencode(params)
response = json.loads(urllib.request.urlopen(url).read())
response['itemListElement']
#for element in response['itemListElement']:
  #print(element['result']['name'] + ' (' + str(element['resultScore']) + ')' + ' ' + element['detailedDescription'])
# Out:
#   File "<ipython-input-30-75288a6de9be>", line 18
#     'indent': True,
#     ^
# IndentationError: unexpected indent

# %%
url = urllib.request.urlopen('https://kgsearch.googleapis.com/v1/entities:search?query=paxos+algorithm+notes&key=AIzaSyAffIrMqkGYI6tgqceJkQm0TjR7cB7NlIc&limit=1&indent=True')

# %%
print(url.read())
# Out:
# b'{\n  "@context": {\n    "kg": "http://g.co/kg",\n    "@vocab": "http://schema.org/",\n    "resultScore": "goog:resultScore",\n    "goog": "http://schema.googleapis.com/",\n    "detailedDescription": "goog:detailedDescription",\n    "EntitySearchResult": "goog:EntitySearchResult"\n  },\n  "@type": "ItemList",\n  "itemListElement": []\n}\n'

# %%
# !pip install anvil
